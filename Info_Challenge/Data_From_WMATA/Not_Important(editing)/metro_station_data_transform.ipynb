# %% [markdown]
# IMPORTANT DATA FOR 2024 (USE FOR COMPARISON)
#
# #Source: https://www.wmata.com/initiatives/ridership-portal/Metrorail-Ridership-Summary.cfm
#
# ALL DATA FOR 2024 ONLY
#
# Average (M-Sun) Daily Enteries Per Day over the Whole Year = 394582
#
# Average over All Stations over Whole Year:
#     Mondays: 339775
#     Tuesdays: 423610
#     Wednesdays: 427648
#     Thursdays: 420062
#     Fridays: 362359
#     Saturdays: 270954
#     Sundays: 204772
#
#         So: Highest mid work week (Tu-Thurs), and lowest on weekends
#             Assumption: That lasrge chunk of people primarily use the metro to commute
#
# Average Daily Entries of all Stations By Month in 2024
#     January: 288410
#     February: 328881
#     March: 372934
#     April: 384630
#     May: 363360
#     June: 360303
#     July: 356562
#     August: 329019
#     September: 365487
#     October: 400764
#     November: 333920
#     December: 314386
#
# So by Season That is (Averaged):
#     Spring (March, April, May): 373641
#     Summer (June, July, August): 348628
#     Fall (September, October, November): 366723
#     Winter (December, January, February): 310559
#
#         So: Summer and Winter = Least Busy , Fall and Spring = Most Busy

# %%
import pandas as pd

# %%
#Initial Dataset Import
#Source = https://opendata.dc.gov/datasets/DCGIS::metro-stations-regional/explore?location=38.892451%2C-77.020630%2C10.39&showTable=true 
df = pd.read_csv("Info_Challenge/Data_From_WMATA/Not_Important(editing)/Metro_Stations_Regional.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 #Initial Dataset Import
#       2 #Source = https://opendata.dc.gov/datasets/DCGIS::metro-stations-regional/explore?location=38.892451%2C-77.020630%2C10.39&showTable=true
# ----> 3 df = pd.read_csv("Info_Challenge/Data_From_WMATA/Not_Important(editing)/Metro_Stations_Regional.csv")
#       4 print(df)
#
# ...

# %%
#drop unneccessary columns
columns_to_drop = ["GIS_ID", "MAR_ID", "GLOBALID", "OBJECTID", "CREATOR", "CREATED", "EDITOR", "EDITED", "SE_ANNO_CAD_DATA", "TRAININFO_URL", "WEB_URL"]
df = df.drop(columns=columns_to_drop)
print(df)

# %%
#ADDED: NUMBER_OF_LINES, STATION_TYPES (2 columns)
#Tried to find but couldn't: Station_Max_Capacity, Number_of_Trains, Number_of_Cars

# %% [markdown]
# Metro Info on Capacity:
#     - Metro can only run a max of 26 trains per hour safely/efficiently at once on each track
#     -120 max passengers per car (section of train)
#     -trains are 6-8 cars long
#     Source: https://www.wmata.com/initiatives/plans/upload/BOS-Corridor-Data-Maps.pdf

# %%
stations = df["NAME"].tolist()
print(stations)
print(len(stations)) #should be 98

# %%
#assign station typesBusiness/Government
"""
Station Type Classification Criteria

Residential:	Located in primarily residential neighborhoods, near apartment complexes, and lacks major attractions or offices.
Student/University:	    Near major universities (GWU, AU, UMD, Howard, Georgetown, Catholic U, etc.), with a high student population.
Tourist:	    Close to landmarks, museums, and major attractions.
Business + Government (Jobs):	In a central business district, near government buildings or office-heavy areas.
Event:	Near stadiums, arenas, or large event venues.
"""
station_types = [
    {"Branch Ave": ["Residential", "Events"]},
    {"Braddock Road": ["Residential", "Jobs"]},
    {"King St-Old Town": ["Residential", "Jobs"]},
    {"Eisenhower Ave": ["Residential", "Jobs"]},
    {"Huntington": ["Residential"]},
    {"Anacostia": ["Residential"]},
    {"Eastern Market": ["Residential", "Tourist"]},
    {"Potomac Ave": ["Residential"]},
    {"Stadium-Armory": ["Events"]},
    {"Rhode Island Ave-Brentwood": ["Residential"]},
    {"Minnesota Ave": ["Residential"]},
    {"Van Ness-UDC": ["University"]},
    {"Cleveland Park": ["Residential"]},
    {"Columbia Heights": ["Residential", "University"]},
    {"Spring Hill": ["Residential"]},
    {"Greensboro": ["Residential"]},
    {"Tysons": ["Jobs"]},
    {"McLean": ["Residential"]},
    {"New Carrollton": ["Residential"]},
    {"Landover": ["Residential"]},
    {"Cheverly": ["Residential"]},
    {"Downtown Largo": ["Residential"]},
    {"NoMa-Gallaudet U": ["University", "Residential"]},
    {"Rosslyn": ["Jobs"]},
    {"Arlington Cemetery": ["Tourist", "Jobs"]},
    {"Dupont Circle": ["Jobs"]},
    {"Pentagon": ["Jobs"]},
    {"Crystal City": ["Jobs"]},
    {"Navy Yard-Ballpark": ["Jobs", "Events"]},
    {"McPherson Sq": ["Jobs"]},
    {"Shaw-Howard U": ["University", "Residential"]},
    {"Southern Avenue": ["Residential"]},
    {"Greenbelt": ["Residential"]},
    {"Tenleytown-AU": ["University"]},
    {"West Falls Church": ["Residential", "Jobs"]},
    {"Wiehle-Reston East": ["Residential"]},
    {"College Park-U of Md": ["University"]},
    {"Capitol Heights": ["Residential"]},
    {"Morgan Boulevard": ["Residential"]},
    {"Georgia Ave-Petworth": ["Residential"]},
    {"Takoma": ["Residential"]},
    {"Glenmont": ["Residential"]},
    {"Wheaton": ["Residential"]},
    {"Forest Glen": ["Residential"]},
    {"Silver Spring": ["Residential", "Jobs"]},
    {"Brookland-CUA": ["University", "Residential"]},
    {"Fort Totten": ["Residential"]},
    {"Hyattsville Crossing": ["Residential"]},
    {"West Hyattsville": ["Residential"]},
    {"Benning Road": ["Residential"]},
    {"Addison Road-Seat Pleasant": ["Residential"]},
    {"Deanwood": ["Residential"]},
    {"Shady Grove": ["Residential"]},
    {"Rockville": ["Residential"]},
    {"Twinbrook": ["Residential"]},
    {"North Bethesda": ["Residential"]},
    {"Grosvenor-Strathmore": ["Residential"]},
    {"Medical Center": ["Residential"]},
    {"Bethesda": ["Jobs", "Residential"]},
    {"Foggy Bottom-GWU": ["University", "Jobs"]},
    {"Court House": ["Residential", "Jobs"]},
    {"Clarendon": ["Residential", "Jobs"]},
    {"East Falls Church": ["Residential", "Jobs"]},
    {"Virginia Square-GMU": ["Residential", "Jobs"]},
    {"Ballston-MU": ["Residential", "Jobs"]},
    {"Farragut West": ["Jobs"]},
    {"Farragut North": ["Jobs"]},
    {"Woodley Park-Zoo/Adams Morgan": ["Tourist"]},
    {"L'Enfant Plaza": ["Jobs", "Tourist"]},
    {"Smithsonian": ["Tourist"]},
    {"Archives-Navy Memorial-Penn Quarter": ["Tourist", "Jobs"]},
    {"Waterfront": ["Residential", "Events"]},
    {"Ronald Reagan Washington National Airport": ["Jobs", "Events"]},
    {"Van Dorn Street": ["Residential"]},
    {"Franconia-Springfield": ["Residential"]},
    {"Federal Center SW": ["Jobs"]},
    {"Judiciary Square": ["Jobs"]},
    {"Capitol South": ["Jobs"]},
    {"Metro Center": ["Jobs"]},
    {"Gallery Pl-Chinatown": ["Jobs", "Tourist"]},
    {"Mt Vernon Sq 7th St-Convention Center": ["Jobs", "Tourist"]},
    {"U Street/African-Amer Civil War Memorial/Cardozo": ["Residential", "Tourist"]},
    {"Union Station": ["Jobs", "Tourist"]},
    {"Congress Heights": ["Residential"]},
    {"Naylor Road": ["Residential"]},
    {"Suitland": ["Residential"]},
    {"Dunn Loring-Merrifield": ["Residential"]},
    {"Vienna/Fairfax-GMU": ["Residential"]},
    {"Friendship Heights": ["Residential"]},
    {"Pentagon City": ["Jobs", "Events"]},
    {"Federal Triangle": ["Jobs"]},
    {"Reston Town Center": ["Residential"]},
    {"Herndon": ["Residential"]},
    {"Innovation Center": ["Residential"]},
    {"Washington Dulles International Airport": ["Jobs", "Events"]},
    {"Loudoun Gateway": ["Residential"]},
    {"Ashburn": ["Residential"]},
    {"Potomac Yard": ["Residential"]},
]

print(len(station_types)) # should be 98

# %%
#make it a single dict
station_type_dict = {}
for station in station_types:
    for name, types in station.items():
        station_type_dict[name] = types

station_types_list = []

for index, row in df.iterrows():
    station_name = row['NAME']
    station_types_list.append(station_type_dict.get(station_name, []))  

df['STATION_TYPE'] = station_types_list

print(df)

# %%
#add NUMBER_OF_LINES
def count_lines(line_str):
    return len(line_str.split(','))

df['NUMBER_OF_LINES'] = df['LINE'].apply(count_lines)

print(df)

# %%
#save as csv and excel (NO NEED TO RUN W/ ACCESS TO REPO)

df.to_csv('metro_stations.csv', index=False)
df.to_excel('metro_stations.xlsx', index=False)
